# %% [markdown]
# # Урок 2. Домашнее задание

# %% [markdown]
# __1.__ Представьте в виде несократимой рациональной дроби

# %% [markdown]
# ### $$a=0.(216)$$
#
# ### $$1000a=216.(216)$$
#
# ### $$1000a=216 + 0.(216)$$
#
# ### $$1000a=216 + a$$
#
# ### $$999a=216$$
#
# ### $$a=\frac{216}{999}=\frac{24}{111}=\frac{8}{37}$$
#
# ### $$0.(216)=\frac{8}{37}$$

# %%
print(8/37)
# Out:
# 0.21621621621621623

# %% [markdown]
# ### $$b=1.0(01)$$
#
# ### $$10b=10.(01)= 10 + 0.(01)$$
#
# ### $$10b=10 + \frac{1}{99} = \frac{991}{99}$$
#
# ### $$b=\frac{991}{990}$$
#
# ### $$1.0(01)=\frac{991}{990}$$

# %%
print(991/990)
# Out:
# 1.001010101010101

# %% [markdown]
# __2.*__ Пусть  x=2/21 . Известно, что для некоторого натурального  k  число  x  записывается в  k  - ичной системе счисления как  0.(13)k=0,131313...k . Найдите  k

# %% [markdown]
# ### $$x=0.(13)k$$
# ### $$k^2 * x=13.(13)k= 13_k + x$$
# ### $$(k^2 - 1)* x =13_k$$
# ### $$x=\frac{13_k}{k^2 - 1} = \frac{k + 3}{k^2 - 1} = \frac{2}{21} $$
# ### $$2k^2 -2 = 21k + 63$$
# ### $$2k^2 -21k - 65 = 0 $$
# ### $$D = 21^2 + 520 = 961 $$
# ### $$k = \frac{21 + 31}{4} = 13  $$

# %% [markdown]
# Ответ: k = 13

# %% [markdown]
# __3.__ Проверьте любым способ, является ли данные логические формулы тавтологией:
# ### $$a)\,\,\, (A \vee B) \rightarrow (B \vee\overline A)$$

# %% [markdown]
# <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th>
#     <th>$ A\vee B$</th>
#     <th>$\overline A$</th>
#     <th>$B\vee \overline A$ </th>
#     <th>$(A \vee  B) \leftrightarrow (B\vee \overline A)$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$1$</td><td>$0$</td><td>$0$</td><td>$0$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$1$</td><td>$0$</td><td>$1$</td><td>$1$</td></tr>
# </tbody>
# </table>

# %% [markdown]
# Вывод: данная логическая формула не является тавтологией

# %% [markdown]
# ### $$b)\,\,\, A \rightarrow (A \vee (\overline B \wedge A))$$

# %% [markdown]
# <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th>
#     <th>$\overline B$</th>
#     <th>$ \overline B\wedge A$</th>
#     <th>$A \vee (\overline B \wedge A)$ </th>
#     <th>$A \rightarrow (A \vee (\overline B \wedge A)$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$1$</td><td>$0$</td><td>$0$</td><td>$1$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$0$</td><td>$0$</td><td>$0$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$0$</td><td>$0$</td><td>$1$</td><td>$1$</td></tr>
# </tbody>
# </table>

# %% [markdown]
# Вывод: данная логическая формула является тавтологией

# %% [markdown]
# __4.__ Сформулируйте словесно высказывания:
# ### $$a)\,\,\, (\overline A \vee B) \rightarrow \overline C$$
# ### $$b)\,\,\, C \rightarrow (A \vee \overline B)$$
#
# - $A:\,\,\,$ сегодня светит солнце;
# - $B:\,\,\,$ сегодня сыро;
# - $C:\,\,\,$ я поеду на дачу.

# %% [markdown]
# а) Ели сегодня не светит солнце или сегодня сыро, то я не поеду на дачу.
#
# б) Если я поеду на дачу,то значит сегодня светит солнце или сегодня не сыро.

# %% [markdown]
# __5.__  Пользуясь правилом построения противоположного высказывания, запишите утверждения, противоположные следующим:
#
# a) На любом курсе каждого факультета есть студенты,  которые не сдали хотя бы 1 экзамен на «отлично».
#
# б) В любом самолете на рейсе Вашингтон-Москва присутствует хотя бы один сотрудник силовых органов, в каждой пуговице одежды которого вмонтирован микрофон.

# %% [markdown]
# Решение:
#
# а) ∀ курсе ∀ факультета ∃ студенты, сдающие ∀ экзамены на «отлично».
#
#  ∃ курс ∃ факультета ∀ студент, не сдающий ∃ экзамены на «отлично».
#
# б) ∀ самолете на рейсе Вашингтон-Москва ∃ сотрудник силовых органов, ∀ пуговице одежды которого вмонтирован микрофон.
#
# ∃ самолете на рейсе Вашингтон-Москва ∀ сотрудник силовых органов, ∃ пуговице одежды которого не вмонтирован микрофон.

# %% [markdown]
# Ответ:
#
# а) Хотя бы на одном факультете есть курс, на котором нету студента, сдавший все экзамены на "отлично".
#
# или
#
# Хотя бы на одном факультете есть курс, на котором ни один из студентов не сдал все экзамены на "отлично"
#
# б) На рейсе Вашингтон-Москва существует такой самолет, где найдетя сотрудник силовых органов, у которого хотя бы одна пуговица будет без микрофона
#
# или
#
# На рейсе Вашингтон-Москва существует такой самолет, где нет сотрудников силовых органов, у которых в одной из пуговиц вмонтирован микрофон

# %% [markdown]
# __6*.__ Прочитайте высказывания, установите их истинность и постройте противоположное высказывание:
#
# ### $$a)\,\,\, \forall x\in\mathbb{R}\,\,\,\exists X\in\mathbb{R}:\,\,\, X>x;$$
# ### $$b)\,\,\, \forall y\in\Bigl[0; \frac{\pi}{2}\Bigr]\,\,\,\exists \varepsilon>0:\,\,\, \sin y<\sin(y+\varepsilon);$$
# ### $$c)\,\,\, \forall y\in\Bigl[0; \pi\Bigr)\,\,\,\exists \varepsilon>0:\,\,\, \cos y>\cos(y+\varepsilon).$$

# %% [markdown]
# а)  Для любого действительного числа существует большее действительное число - истина, т.к. во множестве действительных чисел всегда найдется элемент больше любого другого элемента.
#
# Противоположное высказывание $$\,\,\, \exists x\in\mathbb{R}\,\,\,\forall X\in\mathbb{R}:\,\,\, X<=x;$$
#
#
# б) Для любого угла y, большего или равного 0 и меньшего или равного π/2, существует положительный угол ε, такой, что выполняется неравенство sin(y)<sin(y+ε) - ложь, т.к. max(sin(y))=sin(π/2)=1.
#
# Противоположное высказывание $$\,\,\, \exists y\in\Bigl[0; \frac{\pi}{2}\Bigr]\,\,\,\forall \varepsilon>0:\,\,\, \sin y>=\sin(y+\varepsilon);$$
#
# в) Для любого угла y, большего или равного 0 и меньшего π, существует положительный угол ε, такой, что выполняется неравенство cos(y)>cos(y+ε) - истина, т.к. на этом полуинтервале функция cos убывает
#
# Противоположное высказывание $$\,\,\, \exists y\in\Bigl[0; \pi\Bigr)\,\,\,\forall \varepsilon>0:\,\,\, \cos y<=\cos(y+\varepsilon).$$
